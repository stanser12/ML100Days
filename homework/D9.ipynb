# %% [markdown]
# 作業目標:<br>
# 1.讀取各種檔案格式<br>
# 2.輸出各種檔案格式<br>

# %% [markdown]
# 作業重點:<br>
# 1.不同檔案讀取方式皆不同，須了解檔案格式中的邏輯，例如:csv是以逗號分隔<br>
# 2.讀取、輸出檔案的程式碼不同，須注意使用方式

# %% [markdown]
# 題目: <br>
# 讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案

# %%
import pandas as pd

# %%
#讀取資料夾中boston.csv讀取其欄位CHAS、NOX、RM，輸出成.xlsx檔案

# %%
df = pd.read_csv('boston.csv',header = 0, usecols=['CHAS','NOX','RM'])
df
# Out:
#      CHAS    NOX     RM
# 0     0.0  0.538  6.575
# 1     0.0  0.469  6.421
# 2     0.0  0.469  7.185
# 3     0.0  0.458  6.998
# 4     0.0  0.458  7.147
# 5     0.0  0.458  6.430
# 6     0.0  0.524  6.012
# 7     0.0  0.524  6.172
# 8     0.0  0.524  5.631
# 9     0.0  0.524  6.004
# 10    0.0  0.524  6.377
# 11    0.0  0.524  6.009
# 12    0.0  0.524  5.889
# 13    0.0  0.538  5.949
# 14    0.0  0.538  6.096
# 15    0.0  0.538  5.834
# 16    0.0  0.538  5.935
# 17    0.0  0.538  5.990
# 18    0.0  0.538  5.456
# 19    0.0  0.538  5.727
# 20    0.0  0.538  5.570
# 21    0.0  0.538  5.965
# 22    0.0  0.538  6.142
# 23    0.0  0.538  5.813
# 24    0.0  0.538  5.924
# 25    0.0  0.538  5.599
# 26    0.0  0.538  5.813
# 27    0.0  0.538  6.047
# 28    0.0  0.538  6.495
# 29    0.0  0.538  6.674
# ..    ...    ...    ...
# 476   0.0  0.614  6.484
# 477   0.0  0.614  5.304
# 478   0.0  0.614  6.185
# 479   0.0  0.614  6.229
# 480   0.0  0.532  6.242
# 481   0.0  0.532  6.750
# 482   0.0  0.532  7.061
# 483   0.0  0.532  5.762
# 484   0.0  0.583  5.871
# 485   0.0  0.583  6.312
# 486   0.0  0.583  6.114
# 487   0.0  0.583  5.905
# 488   0.0  0.609  5.454
# 489   0.0  0.609  5.414
# 490   0.0  0.609  5.093
# 491   0.0  0.609  5.983
# 492   0.0  0.609  5.983
# 493   0.0  0.585  5.707
# 494   0.0  0.585  5.926
# 495   0.0  0.585  5.670
# 496   0.0  0.585  5.390
# 497   0.0  0.585  5.794
# 498   0.0  0.585  6.019
# 499   0.0  0.585  5.569
# 500   0.0  0.585  6.027
# 501   0.0  0.573  6.593
# 502   0.0  0.573  6.120
# 503   0.0  0.573  6.976
# 504   0.0  0.573  6.794
# 505   0.0  0.573  6.030
#
# [506 rows x 3 columns]

# %%
df.to_excel('ans1.xlsx')
